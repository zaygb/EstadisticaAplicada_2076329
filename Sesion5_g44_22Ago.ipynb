# %% [markdown]
# ## Estadística Aplicada
# Sesión 5 - 22 Agosto
#
# Cinthia Zaydé García Belmonte 2076329

# %%
## Librerias Cajon
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
## Datos
edades = [23, 25, 30, 19]
personas = ['Juan', 'Pedro', 'Ana', 'Lissa']
dicc_1 = {'Municipio':['Escobedo', 'Apodaca', 'Monterrey', 'Santiago'], 'Nacimientos':[200,350,400,120], 'Muertes': [20, 35, 40, 18], 'Matrimonios':[56,68,70,19]}
datos_mun = pd.DataFrame(dicc_1)

# %%
datos_mun
# Out:
#    Municipio  Nacimientos  Muertes  Matrimonios
# 0   Escobedo          200       20           56
# 1    Apodaca          350       35           68
# 2  Monterrey          400       40           70
# 3   Santiago          120       18           19

# %%
edades, personas
# Out:
# ([23, 25, 30, 19], ['Juan', 'Pedro', 'Ana', 'Lissa'])

# %%
## grafica semana pasada
plt.bar(personas, edades)
plt.title('Edades 4 personas')
plt.xlabel('Nombre')
plt.ylabel('Edad')
plt.show()

# %%
plt.bar(datos_mun['Municipio'], datos_mun['Matrimonios'])
plt.title('Matrimonios en NL')
plt.xlabel('Municipio')
plt.ylabel('Cantidad de matrimonios')
plt.show()

# %%
# juntar dos graficas juntas
fig,(graf1, graf2) = plt.subplots(1,2)

# grafica 1 edades
graf1.bar(personas, edades)

#grafica 2 matrimonios
graf2.bar(datos_mun['Municipio'], datos_mun['Matrimonios'])

plt.show()

# %% [markdown]
# ## graficar con pandas
# el graficador d pandas esta construido sobre matplotlib
#
# dataframe.plot.tipo()

# %%
# barras
datos_mun.plot.bar()
# Out:
# <Axes: >

# %%
datos_mun['Matrimonios'].plot.bar()
plt.title('Matrimonios en NL')
plt.xlabel('Municipio')
plt.ylabel('Cantidad de matrimonios')
plt.show()

# %%
#Barras apiladas
datos_mun.plot.bar(stacked=True)
# Out:
# <Axes: >

# %%
#Graficas de lineas
datos_mun.plot.line();

# %%
## grafica d areas
datos_mun.plot.area();

# %%
##
datos_mun['Nacimientos'].plot.hist();
